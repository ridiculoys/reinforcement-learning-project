# %%
import pandas as pd

def load_data(filename):
    fp = open(filename, "r")
    data = [[int(j.strip()) for j in i.split(" ")] for i in fp]
    df =  pd.DataFrame(data=data, columns=["iter", "p1_win", "p2_win", "draw", "p1_start", "p2_start"])
    fp.close()

    return df

# %%
def plot_data(title, df):
    data = pd.DataFrame({
        'p1': df.loc[:, "p1_win"].tolist(),
        'p2': df.loc[:, "p2_win"].tolist(),
        'draw': df.loc[:, "draw"].tolist()
    }, index=df.loc[:, "iter"].tolist())
    
    print('p1', df.loc[:, "p1_win"].tolist())
    print('p2', df.loc[:, "p2_win"].tolist())
    print('drwas', df.loc[:, "draw"].tolist())
    print('iter', df.loc[:, "iter"].tolist())

    print(data)

    lines = data.plot.line(title=title)

# %%
random_v_random = load_data("1_random_v_random.txt")
q_v_random = load_data("2_q_v_random.txt")
trained_v_random = load_data("3_trained_v_random.txt")
q_v_trained = load_data("4_1_trained_v_q.txt")
trained_v_trained = load_data("5_trained_v_trained.txt")

# %%
data = [random_v_random, q_v_random, trained_v_random, q_v_trained]
for df in data:
    print(df)
# Out:
#      iter  p1_win  p2_win  draw  p1_start  p2_start
# 0     100      44      45    11        42        58
# 1     200      93      81    26        91       109
# 2     500     224     209    67       269       231
# 3    1000     435     432   133       496       504
# 4    2000     874     876   250      1025       975
# 5    5000    2191    2187   622      2422      2578
# 6    8000    3479    3499  1022      4021      3979
# 7   10000    4308    4402  1290      4942      5058
# 8   15000    6643    6557  1800      7459      7541
# 9   20000    8650    8798  2552     10061      9939
# 10  25000   10929   10835  3236     12527     12473
# 11  30000   12945   13124  3931     15026     14974
#      iter  p1_win  p2_win  draw  p1_start  p2_start
# 0     100      47      36    17        46        54
# 1     200      88      82    30        96       104
# 2     500     216     234    50       230       270
# 3    1000     446     437   117       506       494
# 4    2000     945     775   280       998      1002
# 5    5000    2479    1903   618      2479      2521
# 6    8000    4258    2772   970      3940      4060
# 7   10000    5481    3273  1246      4933      5067
# 8   15000    8710    4440  1850      7548      7452
# 9   20000   12046    5444  2510      9991     10009
# 10  25000   15379    6384  3237     12464     12536
# 11  30000   18942    7152  3906     14923     15077
#      iter  p1_win  p2_win  draw  p1_start  p2_start
# 0     100      44      40    16        60        40
# 1     200      85      95    20       104        96
# 2     500     220     200    80       246       254
# 3    1000     447     417   136       514       486
# 4    2000     919     806   275      1004       996
# 5    5000    2453    1874   673      2511      2489
# 6   10000    5218    3531  1251      5022      4978
# 7   15000   10550    2560  1890      7561      7439
# 8   20000   14623    2641  2736     10004      9996
# 9   25000   18569    2732  3699     12475     12525
# 10  30000   22704    2921  4375     15089     14911
#     iter  p1_win  p2_win  draw  p1_start  p2_start
# 0    100      37      46    17        44        56
# 1    200      94      83    23        95       105
# 2    500     223     205    72       248       252
# 3   1000     404     476   120       480       520
# 4   2000     911     854   235       989      1011
# 5   5000    2134    2209   657      2536      2464
# 6   8000    3271    3639  1090      3995      4005
# 7  10000    3901    4594  1505      5006      4994
# 8  15000    6465    5770  2765      7546      7454
# 9  20000    8292    7134  4574      9981     10019

# %%
#test

df = pd.DataFrame({
   'pig': [20, 18, 489, 675, 1776],
   'horse': [4, 25, 281, 600, 1900]
   }, index=[1990, 1997, 2003, 2009, 2014])
print(df)
lines = df.plot.line()
# Out:
#        pig  horse
# 1990    20      4
# 1997    18     25
# 2003   489    281
# 2009   675    600
# 2014  1776   1900

# %%
plot_data("Random vs Random", random_v_random)
# Out:
# p1 [44, 93, 224, 435, 874, 2191, 3479, 4308, 6643, 8650, 10929, 12945]
# p2 [45, 81, 209, 432, 876, 2187, 3499, 4402, 6557, 8798, 10835, 13124]
# drwas [11, 26, 67, 133, 250, 622, 1022, 1290, 1800, 2552, 3236, 3931]
# iter [100, 200, 500, 1000, 2000, 5000, 8000, 10000, 15000, 20000, 25000, 30000]
#           p1     p2  draw
# 100       44     45    11
# 200       93     81    26
# 500      224    209    67
# 1000     435    432   133
# 2000     874    876   250
# 5000    2191   2187   622
# 8000    3479   3499  1022
# 10000   4308   4402  1290
# 15000   6643   6557  1800
# 20000   8650   8798  2552
# 25000  10929  10835  3236
# 30000  12945  13124  3931

# %%
plot_data("Q-learn vs Random", q_v_random)
# Out:
# p1 [47, 88, 216, 446, 945, 2479, 4258, 5481, 8710, 12046, 15379, 18942]
# p2 [36, 82, 234, 437, 775, 1903, 2772, 3273, 4440, 5444, 6384, 7152]
# drwas [17, 30, 50, 117, 280, 618, 970, 1246, 1850, 2510, 3237, 3906]
# iter [100, 200, 500, 1000, 2000, 5000, 8000, 10000, 15000, 20000, 25000, 30000]
#           p1    p2  draw
# 100       47    36    17
# 200       88    82    30
# 500      216   234    50
# 1000     446   437   117
# 2000     945   775   280
# 5000    2479  1903   618
# 8000    4258  2772   970
# 10000   5481  3273  1246
# 15000   8710  4440  1850
# 20000  12046  5444  2510
# 25000  15379  6384  3237
# 30000  18942  7152  3906

# %%
plot_data("Trained Q vs Random", trained_v_random)
# Out:
# p1 [44, 85, 220, 447, 919, 2453, 5218, 10550, 14623, 18569, 22704]
# p2 [40, 95, 200, 417, 806, 1874, 3531, 2560, 2641, 2732, 2921]
# drwas [16, 20, 80, 136, 275, 673, 1251, 1890, 2736, 3699, 4375]
# iter [100, 200, 500, 1000, 2000, 5000, 10000, 15000, 20000, 25000, 30000]
#           p1    p2  draw
# 100       44    40    16
# 200       85    95    20
# 500      220   200    80
# 1000     447   417   136
# 2000     919   806   275
# 5000    2453  1874   673
# 10000   5218  3531  1251
# 15000  10550  2560  1890
# 20000  14623  2641  2736
# 25000  18569  2732  3699
# 30000  22704  2921  4375

# %%
plot_data("Q-learn vs Trained", q_v_trained)
#p1 X = trained
#p2 O = q-learn
# Out:
# p1 [37, 94, 223, 404, 911, 2134, 3271, 3901, 6465, 8292]
# p2 [46, 83, 205, 476, 854, 2209, 3639, 4594, 5770, 7134]
# drwas [17, 23, 72, 120, 235, 657, 1090, 1505, 2765, 4574]
# iter [100, 200, 500, 1000, 2000, 5000, 8000, 10000, 15000, 20000]
#          p1    p2  draw
# 100      37    46    17
# 200      94    83    23
# 500     223   205    72
# 1000    404   476   120
# 2000    911   854   235
# 5000   2134  2209   657
# 8000   3271  3639  1090
# 10000  3901  4594  1505
# 15000  6465  5770  2765
# 20000  8292  7134  4574

# %%
plot_data("Trained against random vs Trained against trained q-learn", trained_v_trained)
#p1 X = trained against random
#p2 O = trained against X earlier
# Out:
# p1 [34, 86, 198, 425, 800, 1603, 2592, 2494, 3033, 4282, 5429]
# p2 [59, 86, 226, 439, 958, 2623, 5442, 8803, 10806, 11571, 13067]
# drwas [7, 28, 76, 136, 242, 774, 1966, 3703, 6161, 9147, 11504]
# iter [100, 200, 500, 1000, 2000, 5000, 10000, 15000, 20000, 25000, 30000]
#          p1     p2   draw
# 100      34     59      7
# 200      86     86     28
# 500     198    226     76
# 1000    425    439    136
# 2000    800    958    242
# 5000   1603   2623    774
# 10000  2592   5442   1966
# 15000  2494   8803   3703
# 20000  3033  10806   6161
# 25000  4282  11571   9147
# 30000  5429  13067  11504
